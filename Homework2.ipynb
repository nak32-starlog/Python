# %% [markdown]
# # Number Guessing Game

# %%
import random 

secret_number = random.randint(1,100);
guess = 0;

while guess != secret_number: 
    guess = int(input("Enter number between 1 to 100: "));

    if guess > secret_number:
        print("Too High!");
    elif guess < secret_number:
        print("Too Low!");
    else:
        print(f"You got it! the number was {secret_number}");
# Out:
# Enter number between 1 to 100:  50
# Too Low!
# Enter number between 1 to 100:  70
# Too Low!
# Enter number between 1 to 100:  90
# Too High!
# Enter number between 1 to 100:  86
# Too High!
# Enter number between 1 to 100:  80
# Too High!
# Enter number between 1 to 100:  75
# Too High!
# Enter number between 1 to 100:  72
# Too Low!
# Enter number between 1 to 100:  73
# Too Low!
# Enter number between 1 to 100:  74
# You got it! the number was 74

# %%
import random

user_score = 0
computer_score = 0
options = ["rock", "paper", "scissors"]

while True:
    user_input = str(input("Rock, Paper, Scissor or 'quit' to exit :")).lower();

    if user_input == "quit":
        break;
    elif user_input not in options:
        print("Invalid choice, please try again");
        continue;

    computer_pick = random.choice(options)
    print(f"Computer Picked {computer_pick}")

    if user_input == computer_pick:
        print("It's tie")
    elif (user_input == "rock" and computer_pick == "scissor") or\
         (user_input == "scissor" and computer_pick == "paper") or\
         (user_input == "paper" and computer_pick == "rock"):
        print("You won!")
        under_score +=1
    elif
# Out:
# Rock, Paper, Scissor or 'quit' to exit : 1
# Rock, Paper, Scissor or 'quit' to exit : 1
# Rock, Paper, Scissor or 'quit' to exit : 1
# Rock, Paper, Scissor or 'quit' to exit : 1
# Rock, Paper, Scissor or 'quit' to exit : exit
# Rock, Paper, Scissor or 'quit' to exit : quit
